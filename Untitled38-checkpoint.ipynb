# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn. ensemble import RandomForestRegressor
from sklearn. metrics import accuracy_score
from sklearn. ensemble import RandomForestRegressor
from sklearn. metrics import accuracy_score
from sklearn.model_selection import train_test_split,GridSearchCV

# %%
# import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression   # not ideal for binary, but kept for reference

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Load data
df = pd.read_csv(r'E:\Yasir project\swat_cloudburst_large_3100.csv')
print("Data shape:", df.shape)
df.head()

# =============================================
# 2. Exploratory Data Analysis & Preprocessing
# =============================================
# Check missing values
print("\nMissing values:\n", df.isnull().sum())

# Fill missing values (e.g., with median - more robust than 22)
df.fillna(df.median(numeric_only=True), inplace=True)

# Alternatively, if you want to use 22 as before:
# df.fillna(22, inplace=True)

# Check data types
df.info()

# Assume target column is 'Cloudburst_Event'
target_col = 'Cloudburst_Event'
feature_cols = ['Max_Daily_Rainfall_mm', 'Pressure_hPa', 'Humidity_%', 'Cloud_Cover_%']

# Verify columns exist
for col in feature_cols + [target_col]:
    if col not in df.columns:
        raise ValueError(f"Column '{col}' not found in CSV. Available: {df.columns.tolist()}")

# Separate features and target
X = df[feature_cols]
y = df[target_col]

# Check class distribution
print("\nClass distribution:\n", y.value_counts(normalize=True))

# Scale features (important for neural networks and logistic regression)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-test split (80-20)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)

print(f"Training set size: {X_train.shape[0]}")
print(f"Test set size: {X_test.shape[0]}")

# =============================================
# 3. Traditional Machine Learning Models
# =============================================
results = {}

# ----- Logistic Regression -----
lr = LogisticRegression(max_iter=1000, random_state=42)
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)
results['Logistic Regression'] = {
    'Accuracy': accuracy_score(y_test, y_pred_lr),
    'Precision': precision_score(y_test, y_pred_lr),
    'Recall': recall_score(y_test, y_pred_lr),
    'F1': f1_score(y_test, y_pred_lr)
}
print("Logistic Regression:")
print(classification_report(y_test, y_pred_lr))

# ----- Random Forest Classifier -----
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
results['Random Forest'] = {
    'Accuracy': accuracy_score(y_test, y_pred_rf),
    'Precision': precision_score(y_test, y_pred_rf),
    'Recall': recall_score(y_test, y_pred_rf),
    'F1': f1_score(y_test, y_pred_rf)
}
print("\nRandom Forest:")
print(classification_report(y_test, y_pred_rf))

# (Optional) Linear Regression – not suitable, but shown for completeness
# lr_reg = LinearRegression()
# lr_reg.fit(X_train, y_train)
# y_pred_reg = (lr_reg.predict(X_test) > 0.5).astype(int)

# =============================================
# 4. Deep Learning: LSTM Model
# =============================================
# LSTM expects 3D input: (samples, timesteps, features)
# Since each sample is independent, we set timesteps = 1
X_train_lstm = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test_lstm = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Build LSTM model
model_lstm = Sequential([
    LSTM(32, input_shape=(1, X_train.shape[1]), activation='tanh', return_sequences=False),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='sigmoid')
])

model_lstm.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_lstm.summary()

# Early stopping to avoid overfitting
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = model_lstm.fit(
    X_train_lstm, y_train,
    validation_split=0.2,
    epochs=60,
    batch_size=16,
    callbacks=[early_stop],
    verbose=1
)

# Evaluate LSTM
y_pred_lstm_proba = model_lstm.predict(X_test_lstm)
y_pred_lstm = (y_pred_lstm_proba > 0.5).astype(int).ravel()

results['LSTM'] = {
    'Accuracy': accuracy_score(y_test, y_pred_lstm),
    'Precision': precision_score(y_test, y_pred_lstm),
    'Recall': recall_score(y_test, y_pred_lstm),
    'F1': f1_score(y_test, y_pred_lstm)
}
print("\nLSTM:")
print(classification_report(y_test, y_pred_lstm))

# =============================================
# 5. Model Comparison & Visualization
# =============================================
# Create comparison DataFrame
comparison_df = pd.DataFrame(results).T
print("\n=== Model Performance Comparison ===")
print(comparison_df.round(4))

# Bar plot of metrics
comparison_df.plot(kind='bar', figsize=(10,6), colormap='viridis')
plt.title('ML vs DL: Performance Comparison')
plt.ylabel('Score')
plt.ylim(0,1)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Confusion matrices
fig, axes = plt.subplots(1, 3, figsize=(15,4))
for i, (name, preds) in enumerate(zip(['Logistic Regression', 'Random Forest', 'LSTM'],
                                       [y_pred_lr, y_pred_rf, y_pred_lstm])):
    cm = confusion_matrix(y_test, preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[i])
    axes[i].set_title(f'{name}\nAccuracy: {results[name]["Accuracy"]:.3f}')
    axes[i].set_xlabel('Predicted')
    axes[i].set_ylabel('Actual')
plt.tight_layout()
plt.show()

# =============================================
# 6. Interactive Prediction with Best Model
# =============================================
# Choose the best model based on F1-score
best_model_name = max(results, key=lambda x: results[x]['F1'])
print(f"\nBest model based on F1-score: {best_model_name}")

if best_model_name == 'Logistic Regression':
    best_model = lr
elif best_model_name == 'Random Forest':
    best_model = rf
else:
    best_model = model_lstm

# Prediction function (handles scaling and LSTM reshaping)
def predict_cloudburst(rainfall, pressure, humidity, cloud_cover):
    # Create input array
    input_data = np.array([[rainfall, pressure, humidity, cloud_cover]])
    # Scale using the same scaler
    input_scaled = scaler.transform(input_data)
    if best_model_name == 'LSTM':
        input_scaled = input_scaled.reshape((1, 1, 4))
        proba = best_model.predict(input_scaled, verbose=0)[0][0]
    else:
        proba = best_model.predict_proba(input_scaled)[0][1] if hasattr(best_model, 'predict_proba') else best_model.predict(input_scaled)[0]
    prediction = 1 if proba >= 0.5 else 0
    return prediction, proba

# Interactive prediction
print("\n--- Cloudburst Prediction ---")
rainfall = float(input('Enter Max Daily Rainfall (mm): '))
pressure = float(input('Enter Pressure (hPa): '))
humidity = float(input('Enter Humidity (%): '))
cloud_cover = float(input('Enter Cloud Cover (%): '))

pred, prob = predict_cloudburst(rainfall, pressure, humidity, cloud_cover)
if pred == 1:
    print(f"\n⚠️ CLOUDBURST ALERT! (Probability: {prob:.2f})")
else:
    print(f"\n✅ No cloudburst predicted. (Probability: {prob:.2f})")
# Out:
# Data shape: (3100, 11)
#
# Missing values:
#  Month                    0
# Avg_Temperature_C        0
# Max_Temperature_C        0
# Min_Temperature_C        0
# Total_Rainfall_mm        0
# Max_Daily_Rainfall_mm    0
# Humidity_%               0
# Wind_Speed_kmh           0
# Cloud_Cover_%            0
# Pressure_hPa             0
# Cloudburst_Event         0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3100 entries, 0 to 3099
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Month                  3100 non-null   object
#  1   Avg_Temperature_C      3100 non-null   float64
#  2   Max_Temperature_C      3100 non-null   float64
#  3   Min_Temperature_C      3100 non-null   float64
#  4   Total_Rainfall_mm      3100 non-null   float64
#  5   Max_Daily_Rainfall_mm  3100 non-null   float64
#  6   Humidity_%             3100 non-null   float64
#  7   Wind_Speed_kmh         3100 non-null   float64
#  8   Cloud_Cover_%          3100 non-null   float64
#  9   Pressure_hPa           3100 non-null   float64
#  10  Cloudburst_Event       3100 non-null   int64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 266.5+ KB
#
# Class distribution:
#  Cloudburst_Event
# 0    0.596129
# 1    0.403871
# Name: proportion, dtype: float64
# Training set size: 2480
# Test set size: 620
# Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       370
#            1       1.00      0.99      1.00       250
#
#     accuracy                           1.00       620
#    macro avg       1.00      1.00      1.00       620
# weighted avg       1.00      1.00      1.00       620
#
#
# Random Forest:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       370
#            1       1.00      1.00      1.00       250
#
#     accuracy                           1.00       620
#    macro avg       1.00      1.00      1.00       620
# weighted avg       1.00      1.00      1.00       620
# A:\Pictures\Saved Pictures\Documents\anaconda\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_5 (LSTM)                        │ (None, 32)                  │           4,736 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,281 (20.63 KB)
#  Trainable params: 5,281 (20.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.8750 - loss: 0.5575 - val_accuracy: 0.9798 - val_loss: 0.3580
# Epoch 2/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9693 - loss: 0.2294 - val_accuracy: 0.9899 - val_loss: 0.1189
# Epoch 3/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9798 - loss: 0.1057 - val_accuracy: 0.9899 - val_loss: 0.0649
# Epoch 4/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9803 - loss: 0.0701 - val_accuracy: 0.9899 - val_loss: 0.0452
# Epoch 5/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9869 - loss: 0.0525 - val_accuracy: 0.9879 - val_loss: 0.0355
# Epoch 6/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9884 - loss: 0.0455 - val_accuracy: 0.9919 - val_loss: 0.0295
# Epoch 7/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9894 - loss: 0.0374 - val_accuracy: 0.9960 - val_loss: 0.0243
# Epoch 8/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9879 - loss: 0.0337 - val_accuracy: 0.9919 - val_loss: 0.0219
# Epoch 9/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9859 - loss: 0.0314 - val_accuracy: 0.9940 - val_loss: 0.0199
# Epoch 10/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9924 - loss: 0.0255 - val_accuracy: 0.9980 - val_loss: 0.0174
# Epoch 11/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9909 - loss: 0.0252 - val_accuracy: 0.9960 - val_loss: 0.0164
# Epoch 12/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9909 - loss: 0.0252 - val_accuracy: 0.9980 - val_loss: 0.0146
# Epoch 13/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9945 - loss: 0.0202 - val_accuracy: 0.9980 - val_loss: 0.0137
# Epoch 14/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9929 - loss: 0.0204 - val_accuracy: 0.9960 - val_loss: 0.0134
# Epoch 15/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9929 - loss: 0.0196 - val_accuracy: 0.9980 - val_loss: 0.0125
# Epoch 16/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9924 - loss: 0.0197 - val_accuracy: 0.9960 - val_loss: 0.0123
# Epoch 17/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9934 - loss: 0.0166 - val_accuracy: 1.0000 - val_loss: 0.0111
# Epoch 18/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9929 - loss: 0.0154 - val_accuracy: 0.9960 - val_loss: 0.0104
# Epoch 19/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9945 - loss: 0.0154 - val_accuracy: 1.0000 - val_loss: 0.0099
# Epoch 20/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9919 - loss: 0.0169 - val_accuracy: 1.0000 - val_loss: 0.0102
# Epoch 21/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9940 - loss: 0.0159 - val_accuracy: 0.9980 - val_loss: 0.0091
# Epoch 22/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9965 - loss: 0.0127 - val_accuracy: 0.9980 - val_loss: 0.0086
# Epoch 23/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9934 - loss: 0.0150 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 24/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9950 - loss: 0.0147 - val_accuracy: 0.9960 - val_loss: 0.0091
# Epoch 25/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9965 - loss: 0.0129 - val_accuracy: 0.9980 - val_loss: 0.0081
# Epoch 26/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9960 - loss: 0.0139 - val_accuracy: 0.9980 - val_loss: 0.0086
# Epoch 27/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9945 - loss: 0.0131 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 28/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9970 - loss: 0.0119 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 29/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9965 - loss: 0.0108 - val_accuracy: 0.9980 - val_loss: 0.0069
# Epoch 30/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9970 - loss: 0.0101 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 31/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9945 - loss: 0.0130 - val_accuracy: 1.0000 - val_loss: 0.0068
# Epoch 32/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9970 - loss: 0.0094 - val_accuracy: 0.9980 - val_loss: 0.0065
# Epoch 33/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9960 - loss: 0.0111 - val_accuracy: 1.0000 - val_loss: 0.0053
# Epoch 34/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9975 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 35/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9975 - loss: 0.0082 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 36/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9980 - loss: 0.0076 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 37/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9975 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 38/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9970 - loss: 0.0086 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 39/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9945 - loss: 0.0109 - val_accuracy: 0.9980 - val_loss: 0.0061
# Epoch 40/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9970 - loss: 0.0114 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 41/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9955 - loss: 0.0087 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 42/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9960 - loss: 0.0101 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 43/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9970 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 44/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9990 - loss: 0.0054 - val_accuracy: 0.9980 - val_loss: 0.0047
# Epoch 45/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9985 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 0.0037
# Epoch 46/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9965 - loss: 0.0089 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 47/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9975 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 0.0037
# Epoch 48/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9955 - loss: 0.0088 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 49/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9965 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 50/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9975 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 51/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9980 - loss: 0.0066 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 52/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9960 - loss: 0.0084 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 53/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9965 - loss: 0.0074 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 54/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9995 - loss: 0.0048 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 55/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9990 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 0.0037
# Epoch 56/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9975 - loss: 0.0063 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 57/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9975 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 58/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9980 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 59/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9985 - loss: 0.0048 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 60/60
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9990 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 0.0031
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
#
# LSTM:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       370
#            1       1.00      0.99      0.99       250
#
#     accuracy                           1.00       620
#    macro avg       1.00      0.99      0.99       620
# weighted avg       1.00      1.00      1.00       620
#
#
# === Model Performance Comparison ===
#                      Accuracy  Precision  Recall     F1
# Logistic Regression    0.9968        1.0   0.992  0.996
# Random Forest          0.9984        1.0   0.996  0.998
# LSTM                   0.9952        1.0   0.988  0.994
# Best model based on F1-score: Random Forest
#
# --- Cloudburst Prediction ---
# Enter Max Daily Rainfall (mm):  7
# Enter Pressure (hPa):  0
# Enter Humidity (%):  9
# Enter Cloud Cover (%):  9
# ✅ No cloudburst predicted. (Probability: 0.01)
# A:\Pictures\Saved Pictures\Documents\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
comparison_df = pd.DataFrame(results).T
print("\n=== Model Performance Comparison ===")
print(comparison_df.round(4))
comparison_df.plot(kind='bar', figsize=(10,6), colormap='viridis')
plt.title('ML vs DL: Performance Comparison')
plt.ylabel('Score')
plt.ylim(0,1)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 3, figsize=(15,4))
for i, (name, preds) in enumerate(zip(['Logistic Regression', 'Random Forest', 'LSTM'],
                                       [y_pred_lr, y_pred_rf, y_pred_lstm])):
    cm = confusion_matrix(y_test, preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[i])
    axes[i].set_title(f'{name}\nAccuracy: {results[name]["Accuracy"]:.3f}')
    axes[i].set_xlabel('Predicted')
    axes[i].set_ylabel('Actual')
plt.tight_layout()
plt.show()
# Out:
# === Model Performance Comparison ===
#                      Accuracy  Precision  Recall     F1
# Logistic Regression    0.9968        1.0   0.992  0.996
# Random Forest          0.9984        1.0   0.996  0.998
# LSTM                   0.9952        1.0   0.988  0.994

# %%
# Out:
# 2026-05-01 02:11:50.389 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:50.390 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:50.987
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run A:\Pictures\Saved Pictures\Documents\anaconda\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-05-01 02:11:50.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:50.988 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:50.991 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:50.995 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:50.998 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:50.999 No runtime found, using MemoryCacheStorageManager
# 2026-05-01 02:11:51.005 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.007 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.013 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.014 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.018 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.029 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.033 No runtime found, using MemoryCacheStorageManager
# 2026-05-01 02:11:51.035 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.038 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.040 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.086 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.087 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.089 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.094 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.095 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.098 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.103 No runtime found, using MemoryCacheStorageManager
# 2026-05-01 02:11:51.108 No runtime found, using MemoryCacheStorageManager
# 2026-05-01 02:11:51.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.252 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.259 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.268 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.309 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.314 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.861 Thread 'Thread-5': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.865 Thread 'Thread-5': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:11:51.871 Thread 'Thread-5': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# A:\Pictures\Saved Pictures\Documents\anaconda\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2026-05-01 02:12:27.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:27.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:27.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:27.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:27.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:27.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:27.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:27.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:27.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:27.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:27.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.531 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.532 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.535 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.544 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.566 Session state does not function when running a script without `streamlit run`
# 2026-05-01 02:12:28.569 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.570 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.574 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.578 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.583 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.585 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.591 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.599 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.601 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.604 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.608 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.613 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.616 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.631 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.635 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 02:12:28.680 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
